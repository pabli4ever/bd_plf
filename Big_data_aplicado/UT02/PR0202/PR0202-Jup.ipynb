# %%
# !hdfs dfs -mkdir /user

# %%
# !hdfs dfs -mkdir /user/hadoop

# %%
# !hdfs dfs -mkdir /user/hadoop/proyecto_datos

# %%
# !hdfs dfs -put ./vehicle_price_prediction.csv /user/hadoop/proyecto_datos/

# %%
# !hdfs dfs -ls /user/hadoop/proyecto_datos
# Out:
# Found 1 items
# -rw-r--r--   3 root supergroup  126967327 2025-11-25 12:06 /user/hadoop/proyecto_datos/vehicle_price_prediction.csv

# %%
# !hdfs dfs -cat /user/hadoop/proyecto_datos/vehicle_price_prediction.csv

# %%
# !hdfs dfs -cat /user/hadoop/proyecto_datos/vehicle_price_prediction.csv | wc -l
# Out:
# 1000001

# %%
# !hdfs dfs -mkdir /user/hadoop/proyecto_datos/procesados

# %%
# !hdfs dfs -mkdir /user/hadoop/proyecto_datos/backup

# %%
# !hdfs dfs -cp /user/hadoop/proyecto_datos/vehicle_price_prediction.csv /user/hadoop/proyecto_datos/backup/

# %%
# !hdfs dfs -mv /user/hadoop/proyecto_datos/vehicle_price_prediction.csv /user/hadoop/proyecto_datos/procesados/

# %%
# !hdfs dfs -ls /user/hadoop/proyecto_datos/*
# Out:
# Found 1 items
# -rw-r--r--   3 root supergroup  126967327 2025-11-25 12:17 /user/hadoop/proyecto_datos/backup/vehicle_price_prediction.csv
# Found 1 items
# -rw-r--r--   3 root supergroup  126967327 2025-11-25 12:06 /user/hadoop/proyecto_datos/procesados/vehicle_price_prediction.csv

# %%
# !hdfs dfs -mkdir -p /compartido

# %%
# !hdfs dfs -cp /user/hadoop/proyecto_datos/procesados/vehicle_price_prediction.csv /compartido/

# %%
# !hdfs dfs -ls /compartido
# Out:
# Found 1 items
# -rw-r--r--   3 root supergroup  126967327 2025-11-25 12:20 /compartido/vehicle_price_prediction.csv

# %%
# !hdfs dfs -get /user/hadoop/proyecto_datos/procesados/vehicle_price_prediction.csv /Downloads

# %%
# !hdfs dfs -ls -h /user/hadoop/proyecto_datos/backup/vehicle_price_prediction.csv
# Out:
# -rw-r--r--   3 root supergroup    121.1 M 2025-11-25 12:17 /user/hadoop/proyecto_datos/backup/vehicle_price_prediction.csv

# %%
# !hdfs dfs -chmod 600 /user/hadoop/proyecto_datos/backup/vehicle_price_prediction.csv

# %%
# !hdfs dfs -ls -h /user/hadoop/proyecto_datos/backup/vehicle_price_prediction.csv
# Out:
# -rw-------   3 root supergroup    121.1 M 2025-11-25 12:17 /user/hadoop/proyecto_datos/backup/vehicle_price_prediction.csv

# %%
# !hdfs dfs -touchz /user/hadoop/proyecto_datos/temporal.txt

# %%
# !hdfs dfs -rm /user/hadoop/proyecto_datos/temporal.txt
# Out:
# Deleted /user/hadoop/proyecto_datos/temporal.txt

# %%
# !hdfs dfsadmin -setQuota 5 /user/hadoop/proyecto_datos

# %%
# !hdfs dfs -count -q /user/hadoop/proyecto_datos
# Out:
#            5               0            none             inf            3            2          253934654 /user/hadoop/proyecto_datos

# %%
# !hdfs dfs -touch /user/hadoop/proyecto_datos/archivo1
# Out:
# touch: The NameSpace quota (directories and files) of directory /user/hadoop/proyecto_datos is exceeded: quota=5 file count=6
